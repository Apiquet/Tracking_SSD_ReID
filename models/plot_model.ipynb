# %%
from SSD300 import SSD300
SSD300_model = SSD300(21)

# %%
from tensorflow.python.keras.utils.vis_utils import plot_model
plot_model(SSD300_model.getModel("conf_concat"), show_shapes=True, expand_nested=False, show_layer_names=True, to_file='model_nexpand_concat.png', dpi=128)

# %%
from tensorflow.python.keras.utils.vis_utils import plot_model
plot_model(SSD300_model.getModel("conf_concat"), show_shapes=True, expand_nested=True, show_layer_names=True, to_file='model_expand_concat.png', dpi=128)
